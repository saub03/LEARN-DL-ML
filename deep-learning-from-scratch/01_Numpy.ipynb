# %% [markdown]
# # Basic Numpy Calculation

# %%
import numpy as np

# %% [markdown]
# ## 넘파이 배열 생성

# %%
num_arr = np.array([1.0, 2.0, 3.0])
num_arr2 = np.array([[1,2,3], [4,5,6]])
print("1차원 배열")
print(num_arr, '\n')
print("2차원 배열")
print(num_arr2)
# Out:
# 1차원 배열
# [1. 2. 3.]
#
# 2차원 배열
# [[1 2 3]
#  [4 5 6]]

# %%
num_arr2.shape
# Out:
# (2, 3)

# %%
num_arr2.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 넘파이 산술 연산

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])

# %%
x+y
# Out:
# array([3., 6., 9.])

# %%
x*y
# Out:
# array([ 2.,  8., 18.])

# %%
x-2
# Out:
# array([-1.,  0.,  1.])

# %%
x*2
# Out:
# array([2., 4., 6.])

# %% [markdown]
# ## 브로드캐스팅

# %%
A = np.array([[1,2], [3,4]])
B = np.array([[3,0],[0,6]])

# %%
A*B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])
